# %%
# 1. Define the edges (The lines connecting the points)
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'), ('V3','V9'),
    ('V4','V5'), ('V5','V6'),('V6','V8'), ('V6','V12'), ('V7','V8'),
    ('V8','V9'), ('V8','V11'), ('V9','V13'), ('V9','V10'), 
    ('V10','V12'), ('V10','V14'), ('V10','V15'), ('V13','V14'), ('V14','V15')
]

# 2. Precise coordinates to match your image's layout and rotation
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9,8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Identify points that were Black in your image (to make them Green)
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 4. Generate the graph
G = Graph(edges)
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 35 graphics primitives

# %%
# 1. Edges (V3 is removed from all connections)
edges = [
    ('V1','V2'), ('V1','V4'), 
    ('V4','V5'), ('V4','V7'), ('V5','V6'), ('V6','V8'), ('V6','V12'), ('V7','V8'),
    ('V8','V9'), ('V8','V11'), ('V9','V13'), ('V9','V10'),
    ('V10','V12'), ('V10','V14'), ('V10','V15'), ('V13','V14'), ('V14','V15')
]

# 2. Coordinates (Matches the rotation of your picture)
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9, 8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Create Graph (Force it to include V3 even though it has no edges)
G = Graph(edges)
G.add_vertex('V3') 

# 4. Define Colors
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 5. Plot
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 33 graphics primitives

# %%
# 1. Edges (All connections to V4 have been removed)
edges = [
    ('V1','V2'), ('V2','V3'), ('V3','V9'),
    ('V5','V6'), ('V6','V8'), ('V6','V12'), ('V7','V8'), ('V7', 'V3'),
    ('V8','V9'), ('V8','V11'), ('V9','V13'), ('V9','V10'),
    ('V10','V12'), ('V10','V14'), ('V10','V15'), ('V13','V14'), ('V14','V15')
]

# 2. Coordinates to maintain the picture's rotation
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9, 8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Create Graph and ensure V4 is included as a floating point
G = Graph(edges)
G.add_vertex('V4')

# 4. Define Colors (Articulation points = green, others = blue)
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 5. Plot the graph
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 33 graphics primitives

# %%
# 1. Edges (All connections to V5 have been removed)
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'), ('V3','V9'),
    ('V6','V8'), ('V6','V12'), ('V7','V8'), ('V8','V9'), ('V8','V11'), 
    ('V9','V13'), ('V9','V10'), ('V10','V12'), 
    ('V10','V14'), ('V10','V15'), ('V13','V14'), ('V14','V15')
]

# 2. Coordinates to maintain the picture's rotation
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9, 8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Create Graph and ensure V5 is included as a floating point
G = Graph(edges)
G.add_vertex('V5')

# 4. Define Colors (Articulation points = green, others = blue)
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 5. Plot the graph
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 33 graphics primitives

# %%
# 1. Edges (All connections to V6 have been removed)
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'), ('V3','V9'),
    ('V4','V5'), ('V7','V8'), ('V8','V9'), ('V8','V11'), 
    ('V9','V13'), ('V9','V10'), ('V10','V12'), 
    ('V10','V14'), ('V10','V15'), ('V13','V14'), ('V14','V15')
]

# 2. Coordinates to maintain the picture's rotation
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9, 8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Create Graph and ensure V6 is included as a floating point
G = Graph(edges)
G.add_vertex('V6')

# 4. Define Colors (Articulation points = green, others = blue)
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 5. Plot the graph with black lines
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 32 graphics primitives

# %%
# 1. Edges (All connections to V9 have been removed)
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'),
    ('V4','V5'), ('V5','V6'), ('V6','V12'), ('V6','V8'),
    ('V7','V8'), ('V8','V11'), ('V10','V12'), 
    ('V10','V14'), ('V10','V15'), ('V13','V14'), ('V14','V15')
]

# 2. Coordinates for the rotated layout
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9, 8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Create Graph and ensure V9 is included as a floating point
G = Graph(edges)
G.add_vertex('V9')

# 4. Define Colors (Articulation points = green, others = blue)
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 5. Plot
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 31 graphics primitives

# %%
# 1. Edges (All connections to V13 have been removed)
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'), ('V3','V9'),
    ('V4','V5'), ('V5','V6'), ('V6','V12'), ('V7','V8'), ('V6','V8'),
    ('V8','V9'), ('V8','V11'), ('V9','V10'),
    ('V10','V12'), ('V10','V14'), ('V10','V15'), ('V14','V15')
]

# 2. Coordinates to maintain the picture's rotation
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10':(4.5, 3.5), 'V11':(3.5, 3), 'V12':(1.5, 2.5),
    'V13':(9, 8.5), 'V14':(9.5, 5.5), 'V15':(4.8, 1)
}

# 3. Create Graph and ensure V13 is included as a floating point
G = Graph(edges)
G.add_vertex('V13')

# 4. Define Colors (Articulation points = green, others = blue)
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 5. Plot the graph
G.plot(pos=pos, 
       edge_color='black', 
       vertex_colors={'green': green_nodes, 'blue': blue_nodes},
       vertex_size=500).show()
# Out:
# Graphics object consisting of 33 graphics primitives

# %%
# 1. Define the edges (all connections of V3 and V4 removed)
edges = [
    ('V5','V6'), ('V6','V8'), ('V6','V12'),
    ('V7','V8'), ('V8','V9'), ('V8','V11'),
    ('V9','V13'), ('V9','V10'),
    ('V10','V12'), ('V10','V14'), ('V10','V15'),
    ('V13','V14'), ('V14','V15')
]

# 2. Precise coordinates (V3 and V4 still included so points remain visible)
pos = {
    'V1': (1, 9),   'V2': (4, 10),  'V3': (4, 8), 
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10': (4.5, 3.5), 'V11': (3.5, 3), 'V12': (1.5, 2.5),
    'V13': (9, 8.5), 'V14': (9.5, 5.5), 'V15': (4.8, 1)
}

# 3. Node colors
green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

# 4. Create graph and explicitly add all vertices
G = Graph()
G.add_vertices(pos.keys())   # keeps all points visible
G.add_edges(edges)

# 5. Plot graph
G.plot(
    pos=pos,
    edge_color='black',
    vertex_colors={'green': green_nodes, 'blue': blue_nodes},
    vertex_size=500
).show()
# Out:
# Graphics object consisting of 29 graphics primitives

# %%
# Remove all connections of V5 and V6
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'), ('V3','V9'),
    ('V7','V8'), ('V8','V9'), ('V8','V11'),
    ('V9','V13'), ('V9','V10'),
    ('V10','V12'), ('V10','V14'), ('V10','V15'),
    ('V13','V14'), ('V14','V15')
]

pos = {
    'V1': (1, 9), 'V2': (4, 10), 'V3': (4, 8),
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10': (4.5, 3.5), 'V11': (3.5, 3), 'V12': (1.5, 2.5),
    'V13': (9, 8.5), 'V14': (9.5, 5.5), 'V15': (4.8, 1)
}

green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

G = Graph()
G.add_vertices(pos.keys())
G.add_edges(edges)

G.plot(
    pos=pos,
    edge_color='black',
    vertex_colors={'green': green_nodes, 'blue': blue_nodes},
    vertex_size=500
).show()
# Out:
# Graphics object consisting of 31 graphics primitives

# %%
# Remove all connections of V9 and V13
edges = [
    ('V1','V2'), ('V1','V4'), ('V2','V3'), ('V3','V4'),
    ('V4','V5'), ('V5','V6'), ('V6','V8'), ('V6','V12'),
    ('V7','V8'), ('V8','V11'),
    ('V10','V12'), ('V10','V14'), ('V10','V15'),
    ('V14','V15')
]

pos = {
    'V1': (1, 9), 'V2': (4, 10), 'V3': (4, 8),
    'V4': (1.5, 7), 'V5': (1, 6.5), 'V6': (0.5, 5),
    'V7': (2.5, 7.5), 'V8': (2.8, 6), 'V9': (4.2, 6.5),
    'V10': (4.5, 3.5), 'V11': (3.5, 3), 'V12': (1.5, 2.5),
    'V13': (9, 8.5), 'V14': (9.5, 5.5), 'V15': (4.8, 1)
}

green_nodes = ['V3', 'V4', 'V5', 'V6', 'V8', 'V9', 'V13']
blue_nodes = [v for v in pos if v not in green_nodes]

G = Graph()
G.add_vertices(pos.keys())
G.add_edges(edges)

G.plot(
    pos=pos,
    edge_color='black',
    vertex_colors={'green': green_nodes, 'blue': blue_nodes},
    vertex_size=500
).show()
# Out:
# Graphics object consisting of 30 graphics primitives
